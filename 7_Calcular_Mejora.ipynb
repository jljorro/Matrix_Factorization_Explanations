# %%
import pandas as pd
import numpy as np

# %%
all_ratings_df = pd.read_csv('data/experiment_data/result_all_values.csv')
all_ratings_df.head()
# Out:
#    userId  movieId  rating  predicted  rating_binary_k_1  rating_q_k_1  \
# 0       1      223     3.0   4.042081                5.0           5.0
# 1       1      349     4.0   2.726556                4.0           5.0
# 2       1      527     5.0   2.743715                5.0           5.0
# 3       4      357     3.0   2.737091                5.0           3.0
# 4       5      110     4.0   3.492654                3.0           4.0
#
#    rating_binary_k_2  rating_q_k_2  rating_binary_k_3  rating_q_k_3  \
# 0                5.0           3.0                4.0           5.0
# 1                3.0           3.0                5.0           5.0
# 2                4.0           3.0                5.0           5.0
# 3                3.0           2.0                3.0           3.0
# 4                3.0           4.0                5.0           3.0
#
#        ...        rating_binary_k_6  rating_q_k_6  rating_binary_k_7  \
# 0      ...                      3.0           4.0                5.0
# 1      ...                      5.0           4.0                5.0
# 2      ...                      4.0           5.0                5.0
# 3      ...                      5.0           NaN                2.0
# 4      ...                      4.0           4.0                5.0
#
#    rating_q_k_7  rating_binary_k_8  rating_q_k_8  rating_binary_k_9  \
# 0           5.0                5.0           4.0                4.0
# 1           5.0                4.0           5.0                4.0
# 2           4.0                4.0           5.0                5.0
# 3           NaN                5.0           NaN                3.0
# 4           3.0                1.0           3.0                3.0
#
#    rating_q_k_9  rating_binary_k_10  rating_q_k_10
# 0           NaN                 4.0            NaN
# 1           NaN                 5.0            NaN
# 2           NaN                 4.0            NaN
# 3           NaN                 2.0            NaN
# 4           NaN                 4.0            NaN
#
# [5 rows x 24 columns]

# %%
for k in range(1, 11):
    all_ratings_df['error_binary_k_{}'.format(k)] = all_ratings_df.apply(lambda row: row['rating_binary_k_{}'.format(k)] - row['predicted'], axis=1)
    
for k in range(1, 11):
    all_ratings_df['error_q_k_{}'.format(k)] = all_ratings_df.apply(lambda row: row['rating_q_k_{}'.format(k)] - row['predicted'], axis=1)

# %%
k_values = [1, 2, 3, 5, 10]

# %%
for k in range(1, 11):
    all_ratings_df.drop(columns='rating_binary_k_{}'.format(k), inplace=True)
    all_ratings_df.drop(columns='rating_q_k_{}'.format(k), inplace=True)

# %%
all_ratings_df.drop(columns=['predicted', 'userId', 'movieId'], inplace=True)
all_ratings_df.head()
# Out:
#    rating  error_binary_k_1  error_binary_k_2  error_binary_k_3  \
# 0     3.0          0.957919          0.957919         -0.042081
# 1     4.0          1.273444          0.273444          2.273444
# 2     5.0          2.256285          1.256285          2.256285
# 3     3.0          2.262909          0.262909          0.262909
# 4     4.0         -0.492654         -0.492654          1.507346
#
#    error_binary_k_4  error_binary_k_5  error_binary_k_6  error_binary_k_7  \
# 0         -0.042081         -0.042081         -1.042081          0.957919
# 1          1.273444          1.273444          2.273444          2.273444
# 2          2.256285          2.256285          1.256285          2.256285
# 3          2.262909         -0.737091          2.262909         -0.737091
# 4          0.507346          0.507346          0.507346          1.507346
#
#    error_binary_k_8  error_binary_k_9      ...       error_q_k_1  error_q_k_2  \
# 0          0.957919         -0.042081      ...          0.957919    -1.042081
# 1          1.273444          1.273444      ...          2.273444     0.273444
# 2          1.256285          2.256285      ...          2.256285     0.256285
# 3          2.262909          0.262909      ...          0.262909    -0.737091
# 4         -2.492654         -0.492654      ...          0.507346     0.507346
#
#    error_q_k_3  error_q_k_4  error_q_k_5  error_q_k_6  error_q_k_7  \
# 0     0.957919     0.957919     0.957919    -0.042081     0.957919
# 1     2.273444     2.273444     1.273444     1.273444     2.273444
# 2     2.256285     2.256285     1.256285     2.256285     1.256285
# 3     0.262909     2.262909          NaN          NaN          NaN
# 4    -0.492654     0.507346     0.507346     0.507346    -0.492654
#
#    error_q_k_8  error_q_k_9  error_q_k_10
# 0    -0.042081          NaN           NaN
# 1     2.273444          NaN           NaN
# 2     2.256285          NaN           NaN
# 3          NaN          NaN           NaN
# 4    -0.492654          NaN           NaN
#
# [5 rows x 21 columns]

# %%
def sum_err(values, k):
    limit = num_err(values, k)
    sum_values = values[:limit]
    
    total = 0.0
    for v in sum_values:
        total += abs(v)
        
    return total

# %%
def num_err(values, k):
    valid_values = np.sum(~np.isnan(values))
    limit = min(k, valid_values)
            
    return limit

# %%
for k in k_values:
    all_ratings_df['sum_err_bin_k_{}'.format(k)] = all_ratings_df.apply(lambda row: sum_err(row.values[1:11], k), axis=1)
    all_ratings_df['num_err_bin_k_{}'.format(k)] = all_ratings_df.apply(lambda row: num_err(row.values[1:11], k), axis=1)
    
for k in k_values:
    all_ratings_df['sum_err_q_k_{}'.format(k)] = all_ratings_df.apply(lambda row: sum_err(row.values[11:21], k), axis=1)
    all_ratings_df['num_err_q_k_{}'.format(k)] = all_ratings_df.apply(lambda row: num_err(row.values[11:21], k), axis=1)

# %%
for k in range(1, 11):
    all_ratings_df.drop(columns='error_binary_k_{}'.format(k), inplace=True)
    all_ratings_df.drop(columns='error_q_k_{}'.format(k), inplace=True)

# %%
sum_values = pd.DataFrame(all_ratings_df.groupby(by='rating').sum())
sum_values.reset_index(inplace=True)
sum_values
# Out:
#    rating  sum_err_bin_k_1  num_err_bin_k_1  sum_err_bin_k_2  num_err_bin_k_2  \
# 0     0.5         5.751753                5        12.002352               10
# 1     1.0        46.904633               37        80.219805               74
# 2     1.5         6.266129                4        10.518486                8
# 3     2.0        79.208324               85       150.141845              169
# 4     2.5        29.133913               34        66.833118               68
# 5     3.0       286.754413              295       539.355658              590
# 6     3.5        90.677855               95       166.661491              190
# 7     4.0       272.783474              304       553.039256              607
# 8     4.5        68.103277               66       129.055658              130
# 9     5.0       236.313668              219       440.993663              433
#
#    sum_err_bin_k_3  num_err_bin_k_3  sum_err_bin_k_5  num_err_bin_k_5  \
# 0        17.491339               15        27.780854               24
# 1       117.231975              110       175.817134              182
# 2        16.325450               12        25.925606               20
# 3       217.806526              251       366.946891              410
# 4        99.938828              102       162.604765              168
# 5       788.819373              881      1324.576185             1444
# 6       241.599666              282       407.599568              461
# 7       826.245740              903      1327.800390             1478
# 8       188.617450              192       294.588206              311
# 9       660.463291              643      1042.615861             1041
#
#    sum_err_bin_k_10       ...        sum_err_q_k_1  num_err_q_k_1  \
# 0         48.061708       ...             4.250599              5
# 1        324.203970       ...            35.514011             37
# 2         52.892048       ...             4.541191              4
# 3        723.476645       ...            82.606604             85
# 4        319.230282       ...            26.104659             32
# 5       2544.720949       ...           266.937072            292
# 6        764.113983       ...            83.713558             93
# 7       2578.628368       ...           276.649044            296
# 8        523.255205       ...            63.062129             63
# 9       1977.666717       ...           223.437540            211
#
#    sum_err_q_k_2  num_err_q_k_2  sum_err_q_k_3  num_err_q_k_3  sum_err_q_k_5  \
# 0       9.602305              9      14.620372             12      21.622724
# 1      69.765285             72     101.082139            106     164.329021
# 2       8.307320              8      11.100512             12      14.531235
# 3     175.121866            164     252.372484            238     393.858551
# 4      59.642067             63      85.321195             94     139.962304
# 5     546.609868            574     800.398976            851    1285.750086
# 6     155.650116            180     226.618552            263     355.096286
# 7     536.914350            576     786.317379            839    1259.972225
# 8     112.275120            115     155.845151            162     228.912451
# 9     425.383810            408     596.885202            588     926.939520
#
#    num_err_q_k_5  sum_err_q_k_10  num_err_q_k_10
# 0             18       35.714688              28
# 1            167      272.900767             296
# 2             18       24.241147              28
# 3            380      660.525374             675
# 4            152      248.487945             267
# 5           1378     2202.201218            2385
# 6            415      604.428282             700
# 7           1340     2107.063408            2246
# 8            245      323.944484             354
# 9            916     1500.434637            1468
#
# [10 rows x 21 columns]

# %%
for k in k_values:
    sum_values['mae_binary_k_{}'.format(k)] = sum_values.apply(lambda row: row['sum_err_bin_k_{}'.format(k)] / row['num_err_bin_k_{}'.format(k)], axis=1)
    sum_values['mae_q_k_{}'.format(k)] = sum_values.apply(lambda row: row['sum_err_q_k_{}'.format(k)] / row['num_err_q_k_{}'.format(k)], axis=1)

# %%
for k in k_values:
    sum_values.drop(columns='sum_err_bin_k_{}'.format(k), inplace=True)
    sum_values.drop(columns='sum_err_q_k_{}'.format(k), inplace=True)

# %%
for k in k_values[1:]:
    sum_values.drop(columns='num_err_bin_k_{}'.format(k), inplace=True)
    sum_values.drop(columns='num_err_q_k_{}'.format(k), inplace=True)

# %%
sum_values.drop(columns='num_err_q_k_1', inplace=True)
sum_values.rename(columns={'num_err_bin_k_1': 'N'}, inplace=True)
sum_values
# Out:
#    rating    N  mae_binary_k_1  mae_q_k_1  mae_binary_k_2  mae_q_k_2  \
# 0     0.5    5        1.150351   0.850120        1.200235   1.066923
# 1     1.0   37        1.267693   0.959838        1.084051   0.968962
# 2     1.5    4        1.566532   1.135298        1.314811   1.038415
# 3     2.0   85        0.931863   0.971842        0.888413   1.067816
# 4     2.5   34        0.856880   0.815771        0.982840   0.946699
# 5     3.0  295        0.972049   0.914168        0.914162   0.952282
# 6     3.5   95        0.954504   0.900146        0.877166   0.864723
# 7     4.0  304        0.897314   0.934625        0.911103   0.932143
# 8     4.5   66        1.031868   1.000986        0.992736   0.976305
# 9     5.0  219        1.079058   1.058946        1.018461   1.042607
#
#    mae_binary_k_3  mae_q_k_3  mae_binary_k_5  mae_q_k_5  mae_binary_k_10  \
# 0        1.166089   1.218364        1.157536   1.201262         1.201543
# 1        1.065745   0.953605        0.966028   0.984006         0.931621
# 2        1.360454   0.925043        1.296280   0.807291         1.322301
# 3        0.867755   1.060389        0.894992   1.036470         0.922802
# 4        0.979792   0.907672        0.967886   0.920805         0.979234
# 5        0.895368   0.940539        0.917297   0.933055         0.909804
# 6        0.856736   0.861667        0.884164   0.855654         0.859521
# 7        0.915001   0.937208        0.898376   0.940278         0.910854
# 8        0.982383   0.962007        0.947229   0.934337         0.929405
# 9        1.027159   1.015111        1.001552   1.011943         1.009014
#
#    mae_q_k_10
# 0    1.275525
# 1    0.921962
# 2    0.865755
# 3    0.978556
# 4    0.930666
# 5    0.923355
# 6    0.863469
# 7    0.938140
# 8    0.915097
# 9    1.022094

# %%
for k in k_values:
    sum_values['improvement_k_{}'.format(k)] = sum_values.apply(lambda row: (row['mae_binary_k_{}'.format(k)] - row['mae_q_k_{}'.format(k)]) / row['mae_binary_k_{}'.format(k)] * 100, axis=1)

# %%
sum_values.to_csv('data/results/mejora_todos.csv', index=False)
